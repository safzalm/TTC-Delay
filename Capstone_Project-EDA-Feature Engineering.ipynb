# %% [markdown]
# ### 1. Add Liberaries

# %%
import pandas as pd
import glob
import requests
import urllib, json

# %% [markdown]
# ### 2. Read and explore the dataset

# %%
#Read and explore the dataset
ttc_df = pd.read_excel("ttc_data.xlsx")

# %%
ttc_df
# Out:
#         Unnamed: 0       Date   Time        Day                 Station  \
# 0                0 2014-01-01  00:21  Wednesday   VICTORIA PARK STATION
# 1                1 2014-01-01  02:06  Wednesday       HIGH PARK STATION
# 2                2 2014-01-01  02:40  Wednesday        SHEPPARD STATION
# 3                3 2014-01-01  03:10  Wednesday       LANSDOWNE STATION
# 4                4 2014-01-01  03:20  Wednesday           BLOOR STATION
# 5                5 2014-01-01  03:29  Wednesday        DUFFERIN STATION
# 6                6 2014-01-01  07:31  Wednesday  NORTH YORK CTR STATION
# 7                7 2014-01-01  07:32  Wednesday        SHEPPARD STATION
# 8                8 2014-01-01  07:34  Wednesday           QUEEN STATION
# 9                9 2014-01-01  07:34  Wednesday       RUNNYMEDE STATION
# 10              10 2014-01-01  07:53  Wednesday       ST ANDREW STATION
# 11              11 2014-01-01  08:20  Wednesday       WELLESLEY STATION
# 12              12 2014-01-01  08:48  Wednesday         KIPLING STATION
# 13              13 2014-01-01  08:49  Wednesday       YONGE SHP STATION
# 14              14 2014-01-01  08:53  Wednesday      ST PATRICK STATION
# 15              15 2014-01-01  08:55  Wednesday       YONGE SHP STATION
# 16              16 2014-01-01  08:58  Wednesday      KENNEDY BD STATION
# 17              17 2014-01-01  09:00  Wednesday            JANE STATION
# 18              18 2014-01-01  09:00  Wednesday        OLD MILL STATION
# 19              19 2014-01-01  09:01  Wednesday           BLOOR STATION
# 20              20 2014-01-01  09:10  Wednesday         WILSON CARHOUSE
# 21              21 2014-01-01  09:23  Wednesday   SHEPPARD WEST STATION
# 22              22 2014-01-01  09:27  Wednesday   SHEPPARD WEST STATION
# 23              23 2014-01-01  09:32  Wednesday   SHEPPARD WEST STATION
# 24              24 2014-01-01  09:38  Wednesday             BAY STATION
# 25              25 2014-01-01  09:38  Wednesday           FINCH STATION
# 26              26 2014-01-01  10:25  Wednesday         COXWELL STATION
# 27              27 2014-01-01  10:52  Wednesday   ST CLAIR WEST STATION
# 28              28 2014-01-01  11:04  Wednesday  NORTH YORK CTR STATION
# 29              29 2014-01-01  11:20  Wednesday        DUFFERIN STATION
# ...            ...        ...    ...        ...                     ...
# 112483        1574 2019-06-30  10:54     Sunday        YONGE BD STATION
# 112484        1575 2019-06-30  11:09     Sunday           KEELE STATION
# 112485        1576 2019-06-30  12:03     Sunday     SPADINA YUS STATION
# 112486        1577 2019-06-30  12:48     Sunday        EGLINTON STATION
# 112487        1578 2019-06-30  12:54     Sunday           UNION STATION
# 112488        1579 2019-06-30  13:11     Sunday   ST GEORGE YUS STATION
# 112489        1580 2019-06-30  13:49     Sunday  S/O EGLINTON TO ST CLA
# 112490        1581 2019-06-30  13:52     Sunday        ST CLAIR STATION
# 112491        1582 2019-06-30  14:12     Sunday        LAWRENCE STATION
# 112492        1583 2019-06-30  15:30     Sunday      DAVISVILLE STATION
# 112493        1584 2019-06-30  16:05     Sunday       BROADVIEW STATION
# 112494        1585 2019-06-30  16:09     Sunday         COXWELL STATION
# 112495        1586 2019-06-30  16:33     Sunday           UNION STATION
# 112496        1587 2019-06-30  16:48     Sunday            JANE STATION
# 112497        1588 2019-06-30  16:49     Sunday        LAWRENCE STATION
# 112498        1589 2019-06-30  17:05     Sunday          WARDEN STATION
# 112499        1590 2019-06-30  18:25     Sunday           UNION STATION
# 112500        1591 2019-06-30  18:39     Sunday           BLOOR STATION
# 112501        1592 2019-06-30  19:05     Sunday      FINCH WEST STATION
# 112502        1593 2019-06-30  19:07     Sunday          WILSON STATION
# 112503        1594 2019-06-30  19:08     Sunday         KIPLING STATION
# 112504        1595 2019-06-30  19:20     Sunday         CHESTER STATION
# 112505        1596 2019-06-30  19:33     Sunday          WARDEN STATION
# 112506        1597 2019-06-30  20:06     Sunday             BAY STATION
# 112507        1598 2019-06-30  20:11     Sunday          WARDEN STATION
# 112508        1599 2019-06-30  21:09     Sunday       LANSDOWNE STATION
# 112509        1600 2019-06-30  21:46     Sunday         COXWELL STATION
# 112510        1601 2019-06-30  21:55     Sunday       GREENWOOD STATION
# 112511        1602 2019-06-30  22:00     Sunday   YUS/BD/SEPPARD SUBWAY
# 112512        1603 2019-06-30  22:45     Sunday   BLOOR DANFORTH SUBWAY
#
#          Code  Min Delay  Min Gap Bound   Line  Vehicle
# 0       MUPR1         55       60     W     BD     5111
# 1        SUDP          3        7     W     BD     5001
# 2       MUNCA          0        0   NaN     YU        0
# 3        SUDP          3        8     W     BD     5116
# 4       MUSAN          5       10     S     YU     5386
# 5       MUPAA          0        0     E     BD     5174
# 6       MUNCA          0        0   NaN     YU        0
# 7       MUNCA          0        0   NaN     YU        0
# 8       MUNCA          0        0   NaN     YU        0
# 9       MUNCA          0        0   NaN     BD        0
# 10      MUNCA          0        0   NaN     YU        0
# 11      MUNCA          0        0   NaN     YU        0
# 12      MUNOA          5        0     E     BD        0
# 13      MUNOA          6       12     E    SHP     5276
# 14       TUSC          0        0     S     YU     5611
# 15      MUNOA         12       18     E    SHP     5282
# 16      MUNOA          5       10     W     BD        0
# 17      MUNOA          5        0     W     BD        0
# 18      MUNOA          5        0     W     BD        0
# 19      MUNOA          3        0     S     YU        0
# 20        SUG          0        0   NaN     YU        0
# 21      MUNOA          5       10     S     YU        0
# 22      MUNOA          5       10     S     YU        0
# 23      MUNOA          5       10     S     YU        0
# 24       SUDP          5       10     E     BD     5214
# 25      MUNOA          0        0     S     YU     5681
# 26       MUTO          5       11     W     BD     5315
# 27       MUSC          0        0     N     YU     5362
# 28      SUEAS          9       14     S     YU     5411
# 29       MUIR          7       12     W     BD     5015
# ...       ...        ...      ...   ...    ...      ...
# 112483  PUMEL          0        0   NaN     BD        0
# 112484   MUSC          0        0     W     BD     5246
# 112485   MUIR          4        8     S     YU     5881
# 112486   MUIS          0        0     N     YU        0
# 112487   MUIS          0        0   NaN     YU        0
# 112488   MUTO          0        0     S     YU     5606
# 112489  PUEWZ          5        9     S     YU     5756
# 112490  PUMEL          0        0     N     YU        0
# 112491    TUO          0        0     S     YU     6036
# 112492   MUDD          0        0     S     YU     5386
# 112493  PUMEL          0        0   NaN     BD        0
# 112494  MUPLC          0        0   NaN     BD        0
# 112495   MUIS          0        0     N     YU        0
# 112496   TUSC          0        0     W     BD     5211
# 112497   MUIR          6       10     N     YU     5421
# 112498    SUO          0        0   NaN     BD        0
# 112499   SUAP          0        0     N     YU        0
# 112500   MUIS          0        0     N     YU        0
# 112501  EUATC          0        0     S     YU     5696
# 112502  MUPAA          3        7     N     YU     5856
# 112503  MUSAN          4        9     E     BD     5156
# 112504   TUSC          0        0     E     BD     5094
# 112505  PUMEL          0        0   NaN     BD        0
# 112506    MUI         12       17     W     BD     5507
# 112507  EUECD          5       10     W     BD        0
# 112508    MUI         10       15     W     BD     5226
# 112509   MUIR          4        8     E     BD     5237
# 112510   TUSC          0        0     E     BD     5086
# 112511    MUO          0        0   NaN  YU/BD        0
# 112512   MUGD          0        0   NaN     BD        0
#
# [112513 rows x 11 columns]

# %% [markdown]
# ### 3. Feature Engineering
#
# After exploration we can add more features to this dataset. Following is the list of features we can add:
#
# - Separate the Bounds (East, West,North,South)
# - Separate Weekend Delays (Weekend Sat, Weend Sun)
# - Isolating the month, year, and day of the week as separate features (Day,Month,Year)
# - Add City Column to the dataset
# - Get part of the day (Morning, Afternoon, Evening,Night)
# - Addt Hour and Minute column from Timestamp
# - Add latitude and longitude (lat,lon)

# %%
#Separate bounds
ttc_df["East Bound"] = ttc_df["Bound"] == 'E'
ttc_df["West Bound"] =ttc_df["Bound"] == 'W'
ttc_df["North Bound"] = ttc_df["Bound"] == 'N'
ttc_df["South Bound"] = ttc_df["Bound"] == 'S'

# Separate Weekend Delays
ttc_df["Weekend-Sat"] = ttc_df["Day"] == 'Saturday'
ttc_df["Weekend-Sun"] = ttc_df["Day"] == 'Sunday'

#Isolating the month, year, and day of the week as separate predictors
#The numeric day of the year (ignoring the calendar year)
#if there were a seasonal component to these data, and it appears
#that there is, then the numeric day of the year would be best. Also, if some
#months showed higher success rates than others those should be taken into further EDA
#the month is preferable.

ttc_df['Year'] = pd.DatetimeIndex(ttc_df['Date']).year
ttc_df['Month'] = pd.DatetimeIndex(ttc_df['Date']).month
ttc_df['Day'] = pd.DatetimeIndex(ttc_df['Date']).day

#add city column
ttc_df['City'] = 'Toronto'
ttc_df
# Out:
#         Unnamed: 0       Date   Time  Day                 Station   Code  \
# 0                0 2014-01-01  00:21    1   VICTORIA PARK STATION  MUPR1
# 1                1 2014-01-01  02:06    1       HIGH PARK STATION   SUDP
# 2                2 2014-01-01  02:40    1        SHEPPARD STATION  MUNCA
# 3                3 2014-01-01  03:10    1       LANSDOWNE STATION   SUDP
# 4                4 2014-01-01  03:20    1           BLOOR STATION  MUSAN
# 5                5 2014-01-01  03:29    1        DUFFERIN STATION  MUPAA
# 6                6 2014-01-01  07:31    1  NORTH YORK CTR STATION  MUNCA
# 7                7 2014-01-01  07:32    1        SHEPPARD STATION  MUNCA
# 8                8 2014-01-01  07:34    1           QUEEN STATION  MUNCA
# 9                9 2014-01-01  07:34    1       RUNNYMEDE STATION  MUNCA
# 10              10 2014-01-01  07:53    1       ST ANDREW STATION  MUNCA
# 11              11 2014-01-01  08:20    1       WELLESLEY STATION  MUNCA
# 12              12 2014-01-01  08:48    1         KIPLING STATION  MUNOA
# 13              13 2014-01-01  08:49    1       YONGE SHP STATION  MUNOA
# 14              14 2014-01-01  08:53    1      ST PATRICK STATION   TUSC
# 15              15 2014-01-01  08:55    1       YONGE SHP STATION  MUNOA
# 16              16 2014-01-01  08:58    1      KENNEDY BD STATION  MUNOA
# 17              17 2014-01-01  09:00    1            JANE STATION  MUNOA
# 18              18 2014-01-01  09:00    1        OLD MILL STATION  MUNOA
# 19              19 2014-01-01  09:01    1           BLOOR STATION  MUNOA
# 20              20 2014-01-01  09:10    1         WILSON CARHOUSE    SUG
# 21              21 2014-01-01  09:23    1   SHEPPARD WEST STATION  MUNOA
# 22              22 2014-01-01  09:27    1   SHEPPARD WEST STATION  MUNOA
# 23              23 2014-01-01  09:32    1   SHEPPARD WEST STATION  MUNOA
# 24              24 2014-01-01  09:38    1             BAY STATION   SUDP
# 25              25 2014-01-01  09:38    1           FINCH STATION  MUNOA
# 26              26 2014-01-01  10:25    1         COXWELL STATION   MUTO
# 27              27 2014-01-01  10:52    1   ST CLAIR WEST STATION   MUSC
# 28              28 2014-01-01  11:04    1  NORTH YORK CTR STATION  SUEAS
# 29              29 2014-01-01  11:20    1        DUFFERIN STATION   MUIR
# ...            ...        ...    ...  ...                     ...    ...
# 112483        1574 2019-06-30  10:54   30        YONGE BD STATION  PUMEL
# 112484        1575 2019-06-30  11:09   30           KEELE STATION   MUSC
# 112485        1576 2019-06-30  12:03   30     SPADINA YUS STATION   MUIR
# 112486        1577 2019-06-30  12:48   30        EGLINTON STATION   MUIS
# 112487        1578 2019-06-30  12:54   30           UNION STATION   MUIS
# 112488        1579 2019-06-30  13:11   30   ST GEORGE YUS STATION   MUTO
# 112489        1580 2019-06-30  13:49   30  S/O EGLINTON TO ST CLA  PUEWZ
# 112490        1581 2019-06-30  13:52   30        ST CLAIR STATION  PUMEL
# 112491        1582 2019-06-30  14:12   30        LAWRENCE STATION    TUO
# 112492        1583 2019-06-30  15:30   30      DAVISVILLE STATION   MUDD
# 112493        1584 2019-06-30  16:05   30       BROADVIEW STATION  PUMEL
# 112494        1585 2019-06-30  16:09   30         COXWELL STATION  MUPLC
# 112495        1586 2019-06-30  16:33   30           UNION STATION   MUIS
# 112496        1587 2019-06-30  16:48   30            JANE STATION   TUSC
# 112497        1588 2019-06-30  16:49   30        LAWRENCE STATION   MUIR
# 112498        1589 2019-06-30  17:05   30          WARDEN STATION    SUO
# 112499        1590 2019-06-30  18:25   30           UNION STATION   SUAP
# 112500        1591 2019-06-30  18:39   30           BLOOR STATION   MUIS
# 112501        1592 2019-06-30  19:05   30      FINCH WEST STATION  EUATC
# 112502        1593 2019-06-30  19:07   30          WILSON STATION  MUPAA
# 112503        1594 2019-06-30  19:08   30         KIPLING STATION  MUSAN
# 112504        1595 2019-06-30  19:20   30         CHESTER STATION   TUSC
# 112505        1596 2019-06-30  19:33   30          WARDEN STATION  PUMEL
# 112506        1597 2019-06-30  20:06   30             BAY STATION    MUI
# 112507        1598 2019-06-30  20:11   30          WARDEN STATION  EUECD
# 112508        1599 2019-06-30  21:09   30       LANSDOWNE STATION    MUI
# 112509        1600 2019-06-30  21:46   30         COXWELL STATION   MUIR
# 112510        1601 2019-06-30  21:55   30       GREENWOOD STATION   TUSC
# 112511        1602 2019-06-30  22:00   30   YUS/BD/SEPPARD SUBWAY    MUO
# 112512        1603 2019-06-30  22:45   30   BLOOR DANFORTH SUBWAY   MUGD
#
#         Min Delay  Min Gap Bound   Line  ...  North Bound  South Bound  \
# 0              55       60     W     BD  ...        False        False
# 1               3        7     W     BD  ...        False        False
# 2               0        0   NaN     YU  ...        False        False
# 3               3        8     W     BD  ...        False        False
# 4               5       10     S     YU  ...        False         True
# 5               0        0     E     BD  ...        False        False
# 6               0        0   NaN     YU  ...        False        False
# 7               0        0   NaN     YU  ...        False        False
# 8               0        0   NaN     YU  ...        False        False
# 9               0        0   NaN     BD  ...        False        False
# 10              0        0   NaN     YU  ...        False        False
# 11              0        0   NaN     YU  ...        False        False
# 12              5        0     E     BD  ...        False        False
# 13              6       12     E    SHP  ...        False        False
# 14              0        0     S     YU  ...        False         True
# 15             12       18     E    SHP  ...        False        False
# 16              5       10     W     BD  ...        False        False
# 17              5        0     W     BD  ...        False        False
# 18              5        0     W     BD  ...        False        False
# 19              3        0     S     YU  ...        False         True
# 20              0        0   NaN     YU  ...        False        False
# 21              5       10     S     YU  ...        False         True
# 22              5       10     S     YU  ...        False         True
# 23              5       10     S     YU  ...        False         True
# 24              5       10     E     BD  ...        False        False
# 25              0        0     S     YU  ...        False         True
# 26              5       11     W     BD  ...        False        False
# 27              0        0     N     YU  ...         True        False
# 28              9       14     S     YU  ...        False         True
# 29              7       12     W     BD  ...        False        False
# ...           ...      ...   ...    ...  ...          ...          ...
# 112483          0        0   NaN     BD  ...        False        False
# 112484          0        0     W     BD  ...        False        False
# 112485          4        8     S     YU  ...        False         True
# 112486          0        0     N     YU  ...         True        False
# 112487          0        0   NaN     YU  ...        False        False
# 112488          0        0     S     YU  ...        False         True
# 112489          5        9     S     YU  ...        False         True
# 112490          0        0     N     YU  ...         True        False
# 112491          0        0     S     YU  ...        False         True
# 112492          0        0     S     YU  ...        False         True
# 112493          0        0   NaN     BD  ...        False        False
# 112494          0        0   NaN     BD  ...        False        False
# 112495          0        0     N     YU  ...         True        False
# 112496          0        0     W     BD  ...        False        False
# 112497          6       10     N     YU  ...         True        False
# 112498          0        0   NaN     BD  ...        False        False
# 112499          0        0     N     YU  ...         True        False
# 112500          0        0     N     YU  ...         True        False
# 112501          0        0     S     YU  ...        False         True
# 112502          3        7     N     YU  ...         True        False
# 112503          4        9     E     BD  ...        False        False
# 112504          0        0     E     BD  ...        False        False
# 112505          0        0   NaN     BD  ...        False        False
# 112506         12       17     W     BD  ...        False        False
# 112507          5       10     W     BD  ...        False        False
# 112508         10       15     W     BD  ...        False        False
# 112509          4        8     E     BD  ...        False        False
# 112510          0        0     E     BD  ...        False        False
# 112511          0        0   NaN  YU/BD  ...        False        False
# 112512          0        0   NaN     BD  ...        False        False
#
#         Weekend-Sat  Weekend-Sun  Year  Month     City  Hour  Minute  \
# 0             False        False  2014      1  Toronto     0      21
# 1             False        False  2014      1  Toronto     2       6
# 2             False        False  2014      1  Toronto     2      40
# 3             False        False  2014      1  Toronto     3      10
# 4             False        False  2014      1  Toronto     3      20
# 5             False        False  2014      1  Toronto     3      29
# 6             False        False  2014      1  Toronto     7      31
# 7             False        False  2014      1  Toronto     7      32
# 8             False        False  2014      1  Toronto     7      34
# 9             False        False  2014      1  Toronto     7      34
# 10            False        False  2014      1  Toronto     7      53
# 11            False        False  2014      1  Toronto     8      20
# 12            False        False  2014      1  Toronto     8      48
# 13            False        False  2014      1  Toronto     8      49
# 14            False        False  2014      1  Toronto     8      53
# 15            False        False  2014      1  Toronto     8      55
# 16            False        False  2014      1  Toronto     8      58
# 17            False        False  2014      1  Toronto     9       0
# 18            False        False  2014      1  Toronto     9       0
# 19            False        False  2014      1  Toronto     9       1
# 20            False        False  2014      1  Toronto     9      10
# 21            False        False  2014      1  Toronto     9      23
# 22            False        False  2014      1  Toronto     9      27
# 23            False        False  2014      1  Toronto     9      32
# 24            False        False  2014      1  Toronto     9      38
# 25            False        False  2014      1  Toronto     9      38
# 26            False        False  2014      1  Toronto    10      25
# 27            False        False  2014      1  Toronto    10      52
# 28            False        False  2014      1  Toronto    11       4
# 29            False        False  2014      1  Toronto    11      20
# ...             ...          ...   ...    ...      ...   ...     ...
# 112483        False        False  2019      6  Toronto    10      54
# 112484        False        False  2019      6  Toronto    11       9
# 112485        False        False  2019      6  Toronto    12       3
# 112486        False        False  2019      6  Toronto    12      48
# 112487        False        False  2019      6  Toronto    12      54
# 112488        False        False  2019      6  Toronto    13      11
# 112489        False        False  2019      6  Toronto    13      49
# 112490        False        False  2019      6  Toronto    13      52
# 112491        False        False  2019      6  Toronto    14      12
# 112492        False        False  2019      6  Toronto    15      30
# 112493        False        False  2019      6  Toronto    16       5
# 112494        False        False  2019      6  Toronto    16       9
# 112495        False        False  2019      6  Toronto    16      33
# 112496        False        False  2019      6  Toronto    16      48
# 112497        False        False  2019      6  Toronto    16      49
# 112498        False        False  2019      6  Toronto    17       5
# 112499        False        False  2019      6  Toronto    18      25
# 112500        False        False  2019      6  Toronto    18      39
# 112501        False        False  2019      6  Toronto    19       5
# 112502        False        False  2019      6  Toronto    19       7
# 112503        False        False  2019      6  Toronto    19       8
# 112504        False        False  2019      6  Toronto    19      20
# 112505        False        False  2019      6  Toronto    19      33
# 112506        False        False  2019      6  Toronto    20       6
# 112507        False        False  2019      6  Toronto    20      11
# 112508        False        False  2019      6  Toronto    21       9
# 112509        False        False  2019      6  Toronto    21      46
# 112510        False        False  2019      6  Toronto    21      55
# 112511        False        False  2019      6  Toronto    22       0
# 112512        False        False  2019      6  Toronto    22      45
#
#             Time-only
# 0          Late Night
# 1          Late Night
# 2          Late Night
# 3          Late Night
# 4          Late Night
# 5          Late Night
# 6       Early Morning
# 7       Early Morning
# 8       Early Morning
# 9       Early Morning
# 10      Early Morning
# 11      Early Morning
# 12      Early Morning
# 13      Early Morning
# 14      Early Morning
# 15      Early Morning
# 16      Early Morning
# 17            Morning
# 18            Morning
# 19            Morning
# 20            Morning
# 21            Morning
# 22            Morning
# 23            Morning
# 24            Morning
# 25            Morning
# 26            Morning
# 27            Morning
# 28            Morning
# 29            Morning
# ...               ...
# 112483        Morning
# 112484        Morning
# 112485        Morning
# 112486        Morning
# 112487        Morning
# 112488           Noon
# 112489           Noon
# 112490           Noon
# 112491           Noon
# 112492           Noon
# 112493           Noon
# 112494           Noon
# 112495           Noon
# 112496           Noon
# 112497           Noon
# 112498            Eve
# 112499            Eve
# 112500            Eve
# 112501            Eve
# 112502            Eve
# 112503            Eve
# 112504            Eve
# 112505            Eve
# 112506            Eve
# 112507            Eve
# 112508          Night
# 112509          Night
# 112510          Night
# 112511          Night
# 112512          Night
#
# [112513 rows x 23 columns]

# %%
ttc_df.dtypes
# Out:
# Unnamed: 0              int64
# Date           datetime64[ns]
# Time                   object
# Day                     int64
# Station                object
# Code                   object
# Min Delay               int64
# Min Gap                 int64
# Bound                  object
# Line                   object
# Vehicle                 int64
# East Bound               bool
# West Bound               bool
# North Bound              bool
# South Bound              bool
# Weekend-Sat              bool
# Weekend-Sun              bool
# Year                    int64
# Month                   int64
# City                   object
# Hour                    int64
# Minute                  int64
# Time-only              object
# dtype: object

# %%
ttc_df[['Hour','Minute']] = ttc_df['Time'].astype(str).str.split(':', expand=True).astype(int)
ttc_df
# Out:
#         Unnamed: 0       Date   Time  Day                 Station   Code  \
# 0                0 2014-01-01  00:21    1   VICTORIA PARK STATION  MUPR1
# 1                1 2014-01-01  02:06    1       HIGH PARK STATION   SUDP
# 2                2 2014-01-01  02:40    1        SHEPPARD STATION  MUNCA
# 3                3 2014-01-01  03:10    1       LANSDOWNE STATION   SUDP
# 4                4 2014-01-01  03:20    1           BLOOR STATION  MUSAN
# 5                5 2014-01-01  03:29    1        DUFFERIN STATION  MUPAA
# 6                6 2014-01-01  07:31    1  NORTH YORK CTR STATION  MUNCA
# 7                7 2014-01-01  07:32    1        SHEPPARD STATION  MUNCA
# 8                8 2014-01-01  07:34    1           QUEEN STATION  MUNCA
# 9                9 2014-01-01  07:34    1       RUNNYMEDE STATION  MUNCA
# 10              10 2014-01-01  07:53    1       ST ANDREW STATION  MUNCA
# 11              11 2014-01-01  08:20    1       WELLESLEY STATION  MUNCA
# 12              12 2014-01-01  08:48    1         KIPLING STATION  MUNOA
# 13              13 2014-01-01  08:49    1       YONGE SHP STATION  MUNOA
# 14              14 2014-01-01  08:53    1      ST PATRICK STATION   TUSC
# 15              15 2014-01-01  08:55    1       YONGE SHP STATION  MUNOA
# 16              16 2014-01-01  08:58    1      KENNEDY BD STATION  MUNOA
# 17              17 2014-01-01  09:00    1            JANE STATION  MUNOA
# 18              18 2014-01-01  09:00    1        OLD MILL STATION  MUNOA
# 19              19 2014-01-01  09:01    1           BLOOR STATION  MUNOA
# 20              20 2014-01-01  09:10    1         WILSON CARHOUSE    SUG
# 21              21 2014-01-01  09:23    1   SHEPPARD WEST STATION  MUNOA
# 22              22 2014-01-01  09:27    1   SHEPPARD WEST STATION  MUNOA
# 23              23 2014-01-01  09:32    1   SHEPPARD WEST STATION  MUNOA
# 24              24 2014-01-01  09:38    1             BAY STATION   SUDP
# 25              25 2014-01-01  09:38    1           FINCH STATION  MUNOA
# 26              26 2014-01-01  10:25    1         COXWELL STATION   MUTO
# 27              27 2014-01-01  10:52    1   ST CLAIR WEST STATION   MUSC
# 28              28 2014-01-01  11:04    1  NORTH YORK CTR STATION  SUEAS
# 29              29 2014-01-01  11:20    1        DUFFERIN STATION   MUIR
# ...            ...        ...    ...  ...                     ...    ...
# 112483        1574 2019-06-30  10:54   30        YONGE BD STATION  PUMEL
# 112484        1575 2019-06-30  11:09   30           KEELE STATION   MUSC
# 112485        1576 2019-06-30  12:03   30     SPADINA YUS STATION   MUIR
# 112486        1577 2019-06-30  12:48   30        EGLINTON STATION   MUIS
# 112487        1578 2019-06-30  12:54   30           UNION STATION   MUIS
# 112488        1579 2019-06-30  13:11   30   ST GEORGE YUS STATION   MUTO
# 112489        1580 2019-06-30  13:49   30  S/O EGLINTON TO ST CLA  PUEWZ
# 112490        1581 2019-06-30  13:52   30        ST CLAIR STATION  PUMEL
# 112491        1582 2019-06-30  14:12   30        LAWRENCE STATION    TUO
# 112492        1583 2019-06-30  15:30   30      DAVISVILLE STATION   MUDD
# 112493        1584 2019-06-30  16:05   30       BROADVIEW STATION  PUMEL
# 112494        1585 2019-06-30  16:09   30         COXWELL STATION  MUPLC
# 112495        1586 2019-06-30  16:33   30           UNION STATION   MUIS
# 112496        1587 2019-06-30  16:48   30            JANE STATION   TUSC
# 112497        1588 2019-06-30  16:49   30        LAWRENCE STATION   MUIR
# 112498        1589 2019-06-30  17:05   30          WARDEN STATION    SUO
# 112499        1590 2019-06-30  18:25   30           UNION STATION   SUAP
# 112500        1591 2019-06-30  18:39   30           BLOOR STATION   MUIS
# 112501        1592 2019-06-30  19:05   30      FINCH WEST STATION  EUATC
# 112502        1593 2019-06-30  19:07   30          WILSON STATION  MUPAA
# 112503        1594 2019-06-30  19:08   30         KIPLING STATION  MUSAN
# 112504        1595 2019-06-30  19:20   30         CHESTER STATION   TUSC
# 112505        1596 2019-06-30  19:33   30          WARDEN STATION  PUMEL
# 112506        1597 2019-06-30  20:06   30             BAY STATION    MUI
# 112507        1598 2019-06-30  20:11   30          WARDEN STATION  EUECD
# 112508        1599 2019-06-30  21:09   30       LANSDOWNE STATION    MUI
# 112509        1600 2019-06-30  21:46   30         COXWELL STATION   MUIR
# 112510        1601 2019-06-30  21:55   30       GREENWOOD STATION   TUSC
# 112511        1602 2019-06-30  22:00   30   YUS/BD/SEPPARD SUBWAY    MUO
# 112512        1603 2019-06-30  22:45   30   BLOOR DANFORTH SUBWAY   MUGD
#
#         Min Delay  Min Gap Bound   Line  ...  West Bound  North Bound  \
# 0              55       60     W     BD  ...        True        False
# 1               3        7     W     BD  ...        True        False
# 2               0        0   NaN     YU  ...       False        False
# 3               3        8     W     BD  ...        True        False
# 4               5       10     S     YU  ...       False        False
# 5               0        0     E     BD  ...       False        False
# 6               0        0   NaN     YU  ...       False        False
# 7               0        0   NaN     YU  ...       False        False
# 8               0        0   NaN     YU  ...       False        False
# 9               0        0   NaN     BD  ...       False        False
# 10              0        0   NaN     YU  ...       False        False
# 11              0        0   NaN     YU  ...       False        False
# 12              5        0     E     BD  ...       False        False
# 13              6       12     E    SHP  ...       False        False
# 14              0        0     S     YU  ...       False        False
# 15             12       18     E    SHP  ...       False        False
# 16              5       10     W     BD  ...        True        False
# 17              5        0     W     BD  ...        True        False
# 18              5        0     W     BD  ...        True        False
# 19              3        0     S     YU  ...       False        False
# 20              0        0   NaN     YU  ...       False        False
# 21              5       10     S     YU  ...       False        False
# 22              5       10     S     YU  ...       False        False
# 23              5       10     S     YU  ...       False        False
# 24              5       10     E     BD  ...       False        False
# 25              0        0     S     YU  ...       False        False
# 26              5       11     W     BD  ...        True        False
# 27              0        0     N     YU  ...       False         True
# 28              9       14     S     YU  ...       False        False
# 29              7       12     W     BD  ...        True        False
# ...           ...      ...   ...    ...  ...         ...          ...
# 112483          0        0   NaN     BD  ...       False        False
# 112484          0        0     W     BD  ...        True        False
# 112485          4        8     S     YU  ...       False        False
# 112486          0        0     N     YU  ...       False         True
# 112487          0        0   NaN     YU  ...       False        False
# 112488          0        0     S     YU  ...       False        False
# 112489          5        9     S     YU  ...       False        False
# 112490          0        0     N     YU  ...       False         True
# 112491          0        0     S     YU  ...       False        False
# 112492          0        0     S     YU  ...       False        False
# 112493          0        0   NaN     BD  ...       False        False
# 112494          0        0   NaN     BD  ...       False        False
# 112495          0        0     N     YU  ...       False         True
# 112496          0        0     W     BD  ...        True        False
# 112497          6       10     N     YU  ...       False         True
# 112498          0        0   NaN     BD  ...       False        False
# 112499          0        0     N     YU  ...       False         True
# 112500          0        0     N     YU  ...       False         True
# 112501          0        0     S     YU  ...       False        False
# 112502          3        7     N     YU  ...       False         True
# 112503          4        9     E     BD  ...       False        False
# 112504          0        0     E     BD  ...       False        False
# 112505          0        0   NaN     BD  ...       False        False
# 112506         12       17     W     BD  ...        True        False
# 112507          5       10     W     BD  ...        True        False
# 112508         10       15     W     BD  ...        True        False
# 112509          4        8     E     BD  ...       False        False
# 112510          0        0     E     BD  ...       False        False
# 112511          0        0   NaN  YU/BD  ...       False        False
# 112512          0        0   NaN     BD  ...       False        False
#
#         South Bound  Weekend-Sat  Weekend-Sun  Year  Month     City  Hour  \
# 0             False        False        False  2014      1  Toronto     0
# 1             False        False        False  2014      1  Toronto     2
# 2             False        False        False  2014      1  Toronto     2
# 3             False        False        False  2014      1  Toronto     3
# 4              True        False        False  2014      1  Toronto     3
# 5             False        False        False  2014      1  Toronto     3
# 6             False        False        False  2014      1  Toronto     7
# 7             False        False        False  2014      1  Toronto     7
# 8             False        False        False  2014      1  Toronto     7
# 9             False        False        False  2014      1  Toronto     7
# 10            False        False        False  2014      1  Toronto     7
# 11            False        False        False  2014      1  Toronto     8
# 12            False        False        False  2014      1  Toronto     8
# 13            False        False        False  2014      1  Toronto     8
# 14             True        False        False  2014      1  Toronto     8
# 15            False        False        False  2014      1  Toronto     8
# 16            False        False        False  2014      1  Toronto     8
# 17            False        False        False  2014      1  Toronto     9
# 18            False        False        False  2014      1  Toronto     9
# 19             True        False        False  2014      1  Toronto     9
# 20            False        False        False  2014      1  Toronto     9
# 21             True        False        False  2014      1  Toronto     9
# 22             True        False        False  2014      1  Toronto     9
# 23             True        False        False  2014      1  Toronto     9
# 24            False        False        False  2014      1  Toronto     9
# 25             True        False        False  2014      1  Toronto     9
# 26            False        False        False  2014      1  Toronto    10
# 27            False        False        False  2014      1  Toronto    10
# 28             True        False        False  2014      1  Toronto    11
# 29            False        False        False  2014      1  Toronto    11
# ...             ...          ...          ...   ...    ...      ...   ...
# 112483        False        False         True  2019      6  Toronto    10
# 112484        False        False         True  2019      6  Toronto    11
# 112485         True        False         True  2019      6  Toronto    12
# 112486        False        False         True  2019      6  Toronto    12
# 112487        False        False         True  2019      6  Toronto    12
# 112488         True        False         True  2019      6  Toronto    13
# 112489         True        False         True  2019      6  Toronto    13
# 112490        False        False         True  2019      6  Toronto    13
# 112491         True        False         True  2019      6  Toronto    14
# 112492         True        False         True  2019      6  Toronto    15
# 112493        False        False         True  2019      6  Toronto    16
# 112494        False        False         True  2019      6  Toronto    16
# 112495        False        False         True  2019      6  Toronto    16
# 112496        False        False         True  2019      6  Toronto    16
# 112497        False        False         True  2019      6  Toronto    16
# 112498        False        False         True  2019      6  Toronto    17
# 112499        False        False         True  2019      6  Toronto    18
# 112500        False        False         True  2019      6  Toronto    18
# 112501         True        False         True  2019      6  Toronto    19
# 112502        False        False         True  2019      6  Toronto    19
# 112503        False        False         True  2019      6  Toronto    19
# 112504        False        False         True  2019      6  Toronto    19
# 112505        False        False         True  2019      6  Toronto    19
# 112506        False        False         True  2019      6  Toronto    20
# 112507        False        False         True  2019      6  Toronto    20
# 112508        False        False         True  2019      6  Toronto    21
# 112509        False        False         True  2019      6  Toronto    21
# 112510        False        False         True  2019      6  Toronto    21
# 112511        False        False         True  2019      6  Toronto    22
# 112512        False        False         True  2019      6  Toronto    22
#
#        Minute
# 0          21
# 1           6
# 2          40
# 3          10
# 4          20
# 5          29
# 6          31
# 7          32
# 8          34
# 9          34
# 10         53
# 11         20
# 12         48
# 13         49
# 14         53
# 15         55
# 16         58
# 17          0
# 18          0
# 19          1
# 20         10
# 21         23
# 22         27
# 23         32
# 24         38
# 25         38
# 26         25
# 27         52
# 28          4
# 29         20
# ...       ...
# 112483     54
# 112484      9
# 112485      3
# 112486     48
# 112487     54
# 112488     11
# 112489     49
# 112490     52
# 112491     12
# 112492     30
# 112493      5
# 112494      9
# 112495     33
# 112496     48
# 112497     49
# 112498      5
# 112499     25
# 112500     39
# 112501      5
# 112502      7
# 112503      8
# 112504     20
# 112505     33
# 112506      6
# 112507     11
# 112508      9
# 112509     46
# 112510     55
# 112511      0
# 112512     45
#
# [112513 rows x 22 columns]

# %%
#Craete a function to get part of the day(morning, noon,afternoon evening and night) from Timestamp
def f(x):
    if (x > 4) and (x <= 8):
        return 'Early Morning'
    elif (x > 8) and (x <= 12 ):
        return 'Morning'
    elif (x > 12) and (x <= 16):
        return'Noon'
    elif (x > 16) and (x <= 20) :
        return 'Eve'
    elif (x > 20) and (x <= 24):
        return'Night'
    elif (x <= 4):
        return'Late Night'

# %%
ttc_df['Time-only'] = ttc_df['Hour'].apply(f)
ttc_df['Time-only']
# Out:
# 0            Late Night
# 1            Late Night
# 2            Late Night
# 3            Late Night
# 4            Late Night
# 5            Late Night
# 6         Early Morning
# 7         Early Morning
# 8         Early Morning
# 9         Early Morning
# 10        Early Morning
# 11        Early Morning
# 12        Early Morning
# 13        Early Morning
# 14        Early Morning
# 15        Early Morning
# 16        Early Morning
# 17              Morning
# 18              Morning
# 19              Morning
# 20              Morning
# 21              Morning
# 22              Morning
# 23              Morning
# 24              Morning
# 25              Morning
# 26              Morning
# 27              Morning
# 28              Morning
# 29              Morning
#               ...
# 112483          Morning
# 112484          Morning
# 112485          Morning
# 112486          Morning
# 112487          Morning
# 112488             Noon
# 112489             Noon
# 112490             Noon
# 112491             Noon
# 112492             Noon
# 112493             Noon
# 112494             Noon
# 112495             Noon
# 112496             Noon
# 112497             Noon
# 112498              Eve
# 112499              Eve
# 112500              Eve
# 112501              Eve
# 112502              Eve
# 112503              Eve
# 112504              Eve
# 112505              Eve
# 112506              Eve
# 112507              Eve
# 112508            Night
# 112509            Night
# 112510            Night
# 112511            Night
# 112512            Night
# Name: Time-only, Length: 112513, dtype: object

# %%
len(ttc_df['Station'].unique())
# Out:
# 464

# %%
#Get the list of all stations in dataset
stations = list(ttc_df['Station'].unique())
stations
# Out:
# ['VICTORIA PARK STATION',
#  'HIGH PARK STATION',
#  'SHEPPARD STATION',
#  'LANSDOWNE STATION',
#  'BLOOR STATION',
#  'DUFFERIN STATION',
#  'NORTH YORK CTR STATION',
#  'QUEEN STATION',
#  'RUNNYMEDE STATION',
#  'ST ANDREW STATION',
#  'WELLESLEY STATION',
#  'KIPLING STATION',
#  'YONGE SHP STATION',
#  'ST PATRICK STATION',
#  'KENNEDY BD STATION',
#  'JANE STATION',
#  'OLD MILL STATION',
#  'WILSON CARHOUSE',
#  'SHEPPARD WEST STATION',
#  'BAY STATION',
#  'FINCH STATION',
#  'COXWELL STATION',
#  'ST CLAIR WEST STATION',
#  'DUPONT STATION',
#  'YORK MILLS STATION',
#  'DUNDAS WEST STATION',
#  'OSGOODE STATION',
#  'COLLEGE STATION',
#  'YONGE BD STATION',
#  'ST GEORGE YUS STATION',
#  'MCCOWAN STATION',
#  'BROADVIEW STATION',
#  'EGLINTON STATION',
#  'ROSEDALE STATION',
#  'PAPE STATION',
#  'GREENWOOD STATION',
#  'LAWRENCE EAST STATION',
#  'KENNEDY SRT STATION',
#  'ISLINGTON STATION',
#  'WARDEN STATION',
#  'DAVISVILLE STATION',
#  'LAWRENCE STATION',
#  'EGLINTON WEST STATION',
#  'KEELE STATION',
#  'MIDLAND STATION',
#  'YONGE UNIVERSITY LINE',
#  'ELLESMERE STATION',
#  'UNION STATION',
#  'CHESTER STATION',
#  'GLENCAIRN STATION',
#  'WILSON STATION',
#  'YORKDALE STATION',
#  'MUSEUM STATION',
#  'DAVISVILLE HOSTLER',
#  'LESLIE STATION',
#  'DUNDAS STATION',
#  'SHERBOURNE STATION',
#  'BLOOR DANFORTH SUBWAY',
#  'KING STATION',
#  'GREENWOOD YARD',
#  'BATHURST STATION',
#  'LAWRENCE WEST STATION',
#  'DONLANDS STATION',
#  'BAYVIEW STATION',
#  'DON MILLS STATION',
#  "QUEEN'S PARK STATION",
#  'SPADINA YUS STATION',
#  'SUMMERHILL STATION',
#  'ROYAL YORK STATION',
#  'MAIN STREET STATION',
#  'OSSINGTON STATION',
#  'CASTLE FRANK STATION',
#  'ST GEORGE BD STATION',
#  'CHRISTIE STATION',
#  'SCARB CTR STATION',
#  'WILSON HOSTLER',
#  'WOODBINE STATION',
#  'ST CLAIR STATION',
#  'SPADINA BD STATION',
#  'MCCOWAN STATION TO KEN',
#  'WILSON YARD',
#  'GREENWOOD PORTAL',
#  'DAVISVILLE YARD',
#  'GREENWOOD WYE',
#  'TORONTO TRANSIT COMMIS',
#  'BESSARION STATION',
#  'MCBRIEN BUILDING',
#  'RONCEVALLES DIVISION',
#  'MCCOWAN YARD',
#  'GREENWOOD CARHOUSE',
#  'DAVISVILLE CARHOUSE',
#  'DANFORTH DIVISION',
#  'KEELE YARD',
#  'GREENWOOD SHOP',
#  'TRANSIT CONTROL CENTRE',
#  'SHEPPARD LINE',
#  'CHESTER TO BROADVIEW',
#  'KENNEDY STATION TO KIP',
#  'RUSSELL HILL EMERGENCY',
#  'FINCH TO DOWNSVIEW',
#  'EGLINTON TO LAWRENCE S',
#  'YUS/BD/SHEPPARD SUBWAY',
#  'EGLINTON WEST TO BLOOR',
#  'FENMAR AND WESTON',
#  'DUPLEX AVENUE',
#  'SYSTEM WIDE',
#  'GUNN BUILDING',
#  'BLOOR TO KING STATIONS',
#  'YUS/BD/SRT',
#  'ST GEORGE TO LAWRENCE',
#  'CHESTER TO CASTLEFRANK',
#  'LYTTON EMERGENCY EXIT',
#  'ASQUITH SUBSTATION',
#  'DUNCAN SHOP',
#  'BLOOR TO YORK MILLS',
#  'PAPE TO ST GEORGE',
#  'BLOOR TO DAVISVILLE',
#  'INGLIS BUILDING',
#  'FINCH TO LAWRENCE STAT',
#  '(APPROACHING)',
#  'DAVENPORT BUILDING',
#  'VARIOUS',
#  'CLANTON PARK EMERGENCY',
#  'PRINCE EDWARD VIADUCT',
#  'MOORE GATE',
#  'PLANT OPS BLDG',
#  'EGLINTON TO FINCH',
#  'BLOOR YONGE LINES',
#  'KIPLING STATION (ENTER',
#  'UNION STATION (DOWNSVI',
#  'JANE STATION (APPROACH',
#  'DOWNSVIEW STATION',
#  'WOODBINE STATION (LEAV',
#  'KENNEDY BD STATION (AP',
#  'YONGE-UNIVERSITY AND B',
#  'OLD MILL STATION (EXIT',
#  'YONGE-UNIVERSITY LINE',
#  'OLD MILL STATION (APPR',
#  'ST GEORGE STATION',
#  'DUPONT STATION (APPROA',
#  'YORK MILLS STATION (AP',
#  'SHEPPARD SUBWAY LINE',
#  'DUNDAS STATION E/S 1',
#  'ISLINGTON STATION (APP',
#  'KENNEDY STATION (PALTF',
#  'HIGH PARK STATION (ENT',
#  'YONGE UNIVERSITY SUBWA',
#  'WILSON STATION (APPROA',
#  'ROYAL YORK STATION (AP',
#  'KENNEDY',
#  'MCCOWAN STATION (APPRO',
#  'KENNEDY SRT STATION (A',
#  'DUPONT STATION (LEAVIN',
#  'UNION STATION (ST ANDR',
#  'ST GEORGE BD STATION -',
#  'WELLESLEY STATION (APP',
#  'WOODBINE STATION (APPR',
#  'KIPLING STATION (LEAVI',
#  'DOWNSVIEW STATION PLAT',
#  'ROYAL YORK STATION (LE',
#  'ST CLAIR STATION (APPR',
#  'DAVISVILLE STATION - L',
#  'YONGE - UNIVERSITY SUB',
#  'YORK MILLS STATION (LE',
#  'DUNDAS STATION - EAST',
#  'KENNEDY BD STATION PLA',
#  'UNION STATION (TO ST A',
#  'WARDEN STATION (LEAVIN',
#  'KEELE STATION (APPROAC',
#  'YONGE UNIVESITY AND BL',
#  'DONLANDS TO KIPLING ST',
#  'KIPLING STATION (APPRO',
#  'SCARBOROUGH RAPID TRAN',
#  'SHEPPARD STATION (ENTE',
#  'GLENCAIRN STATION (APP',
#  'KEELE STATION (EXITING',
#  'OSGOODE',
#  'ROSEDALE STATION (APP',
#  'QUEEN STATION - EAST S',
#  'KIPLING STATION (PLATF',
#  'COXWELL STATION (ENTER',
#  'ST CLAIR WEST CENTRE T',
#  'CHESTER STATION (ENTER',
#  'DUNDAS STATION - W/S',
#  'KENNEDY SRT STATION [A',
#  'FINCH STATION BOOTH 2',
#  'YONGE-UNIVERSITY/BLOOR',
#  'YONGE-UNIVERSITY SUBWA',
#  'ROYAL YORK STATION (EN',
#  'YONGE STATION',
#  'CHRISTIE STATION (APPR',
#  'KENNEDY STATION',
#  'KENNEDY BD STATION (EN',
#  'DUNDAS WEST STATION (A',
#  'BLOOR-DANFORTH SUBWAY',
#  'YONGE UNIVERSITY',
#  'EGLINTON STATION (APPR',
#  'JANE STATION (ENTERING',
#  'LAWRENCE STATION (LEAV',
#  'ST ANDREW STATION (LEA',
#  'DONLANDS STATION (APPR',
#  'SPADINA STATION',
#  'WOODBINE STATION (EXIT',
#  'MCCOWAN STATION (DEPAR',
#  'KENNEDY SRT STATION (E',
#  'FINCH STATION (APPROAC',
#  'BLOOR/DANFORTH LINE',
#  'YONGE/UNIVERSITY - BLO',
#  'SHERBOURNE STATION (EN',
#  'YONGE - UNIVERSITY LIN',
#  'SHERBOURNE STATION (AP',
#  'KENNEDY BD STATION (EX',
#  'GLENACAIRN STATION (AP',
#  'OSSINGTON STATION (APP',
#  'BLOOR DANFORTH/YONGE U',
#  'KEELE STATION (CROSSIN',
#  'ISLINGTON STATION (ENT',
#  'FINCH STATION (EXITING',
#  'FINCH STATION (PLATFOR',
#  'DUPONT STATION (EXITIN',
#  'YONGE STATION (EXITING',
#  'KENNEDY SRT STATION TO',
#  'EGLINTON STATION (EXIT',
#  'YORKDALE STATION (EXIT',
#  'YONGE/UNIVERSITY',
#  'FINCH STATION (LEAVING',
#  'OSSINGTON STATION (EXI',
#  'BLOOR DANFORTH LINE',
#  'DOWNSVIEW PARK STATION',
#  'LEAVING KENNEDY STATIO',
#  'COXWELL STATION (LEAVI',
#  'ENTERING LESLIE STATIO',
#  'SCARB CENTRE STATION',
#  'KENNEDY PLATFORM 1',
#  'YONGE/UNIVERSITY LINE',
#  'FULL LINE',
#  'BLOOR STATION (STATION',
#  'HIGH PARK STATION (APP',
#  'ISLINGTON STATION (LEA',
#  'YONGE SHP STATION (LEA',
#  'DUNDAS STATION E/S',
#  'ST GEORGE STN',
#  'DUNDAS STATION (W/S)',
#  'DONLANDS STATION (ENTE',
#  'JANE STATION (EXITING)',
#  'COXWELL STATION (EXITI',
#  'MUSEUM STATION (APPROA',
#  'KENNEDY BD STATION (LE',
#  'KEELE STATION (ENTERIN',
#  'MCCOWAN STATION (ENTER',
#  'KENNEDY SRT STATION (L',
#  'MUSEUM STATION (LEAVIN',
#  'SHEPPARD STATION (APPR',
#  'ELLESMERE STATION DEPA',
#  'DUNDAS STATION - WEST',
#  'YONGE-UNIVERSITY SUBW',
#  'KIPLING STATION (EXITI',
#  'ISLINGTON STATION (EXI',
#  'KENNEDY BD STATION (PL',
#  'UNION STATION (APPROAC',
#  'ROSEDALE STATION (APPR',
#  'CHRISTIE STATION (LEAV',
#  'BLOOR - DANFORTH LINE',
#  'UNION TO KING',
#  'BROADVIEW TO SHERBOURN',
#  'UNION STATION (ENTERIN',
#  'BROADVIEW TO YONGE STA',
#  '169 DANFORTH AVENUE',
#  'BROADVIEW AND DANFORTH',
#  'WARDEN STATION (APPR',
#  'ST CLAIR STATION - UPP',
#  'BROADVIEW TO ST GEORGE',
#  'DUPONT STATION ( APPRO',
#  'ST CLAIR STATION PLEAS',
#  'CHESTER STATION (LEAVI',
#  'LESLIE STATION APROACH',
#  'UNION STATION - SALES',
#  'UNION STATION - BOOTH',
#  'ISLINGTON STATION ( AP',
#  'KENNEDY BD STATION ( A',
#  'DUPONT STATION APPROAC',
#  'WILSON STATION (EXITIN',
#  'ST CLAIR WEST',
#  'ST GEORGE TO BROADVIEW',
#  'BESSARIAN STATION',
#  'DOWNSVIEWSTATION',
#  'YONGE/UNIVERSITY BLOOR',
#  'YONGE UNIVERSITY/BLOOR',
#  'YONGE/UNIVERISITY-BLOO',
#  'YONGE/UNIVERSITY & BLO',
#  'YONGE/UINVERSITY & BLO',
#  'SHEPPARD STATION TO YO',
#  'YONGE/UNIVERSITY AND B',
#  'YONGE UNIVERSITY AND B',
#  'UNION STATION TO KING',
#  'WELLESLEY TO COLLEGE',
#  'SHEPPARD TO BAYVIEW',
#  'MCCOWAN CARHOUSE',
#  'HARVEY SHOP',
#  'KIPLING TO ISLINGTON',
#  'KIPLING TO ROYAL YORK',
#  'BLOOR STATON',
#  'UNION TO ST ANDREW',
#  'VICTORIA PARK',
#  'YONGE UNIVERSTIY SUBWA',
#  'WARDEN STATION TO KENN',
#  'MC BRIEN BUILDING',
#  'WILSON TO SHEPPARD WES',
#  'YORK UNIVERSITY STATIO',
#  'EGLINTON WEST TO ST CL',
#  'UNION TO KING STATION',
#  'UNION STATION TO ST AN',
#  'YORK MILLS STATION (A',
#  'WILSON STRUCTURE BUILD',
#  'SHEPPARD WYE',
#  'ATC TERRIROTY',
#  'YORKDALE TO DUPONT STA',
#  'DUPONT TO ST CLAIR WES',
#  'QUEENS QUAY STATION',
#  'HIGHWAY 407 STATION',
#  'CLANTON PARK PORTAL',
#  'GLENAYR EMERGENCY EXIT',
#  'DANFORTH AND COXWELL',
#  'FINCH TO SHEPPARD WEST',
#  'VMC STATION',
#  'VAUGHAN MC STATION',
#  'EGLINTON POCKET',
#  'DOWNSVIEW PARK TO VMC',
#  'SHEPPARD WEST PORTAL',
#  'FINCH WEST STATION',
#  'PIONEER VILLAGE STATIO',
#  'WILSON CAPITAL SHOP',
#  'LEAVING YONGE-SHEPPARD',
#  'BAY LOWER',
#  'YONGE - UNIVERSITY BLO',
#  'KIPLING STATION TO KEN',
#  'TYSSE LINE',
#  'SHEPPARD WEST MIGRATI',
#  'UNION TO ST GEORGE',
#  'LAWRENCE EAST TO ELLES',
#  'SUBWAY OPS BUILDING',
#  'EGLINTON WEST TO VMC',
#  'WARDEN TO KENNEDY STAT',
#  'UNION STATION TO FINCH',
#  'OSSINGTON AND DUFFERIN',
#  'LEAVING LAWRENCE EAST',
#  'MCCOWAN TO KENNEDY STA',
#  'SEHPPARD STATION',
#  'OAKVALE SUBSTATION',
#  'DUFFERIN TO LANSDOWNE',
#  'WILSON TO EGLINTON',
#  'DUNCAN SHOPS',
#  'YU/DB/SHEPPARD SUBWAY',
#  'KING STATION TO UNION',
#  'GREENWOOD COMPLEX',
#  'LEAVING YONGE/SHEPPARD',
#  'GLENCAIRN TO ST GEORGE',
#  'ST CLAIR WEST TO EGLIN',
#  'SHEPPARD WEST MIGRATIO',
#  'ST CLAIR WEST TO DUPON',
#  'OLD MILL TO ISLINGTON',
#  'SRT LINE',
#  'TRANSIT CONTROL',
#  'KING TO UNION',
#  'LESLIE STATION(APPROAC',
#  'OSGOODE POCKET',
#  'SHEPPARD WEST TO WILSO',
#  'DUPONT TO OSGOODE',
#  'GREENWOOD WYE (ENTERI',
#  'EGINTON STATION',
#  'VMC TO SHEPPARD WEST',
#  'ATC FAILURE',
#  'WILSON DIVISION',
#  'KING TO S/O ST ANDREW',
#  'KENNEDY SRT TO MCCOWAN',
#  'WELLSLEY STATION',
#  'WILSON HOSLTER',
#  'SHEPPARD YONGE STATION',
#  'SCARBOROUGH SRT LINE',
#  '40 CARL HALL ROAD UNIT',
#  'GREENWOOD SHOPS',
#  'SHEPPARD WEST',
#  'KEELE TO DUNDAS WEST',
#  'SCARBOROUGH RAOID TRAN',
#  'SOUTH OF LAWRENCE SRT',
#  'SOUTH OF MIDLAND SRT',
#  'DAVISVILLE BUILD UP',
#  'GUNN THEATRE',
#  'QUEENS PARK STATION',
#  'WELBECK EMERGENCY EXIT',
#  'SYSTEMWIDE',
#  'ST CLAIR TO LAWRENCE S',
#  'CHURCH EMERGENCY EXIT',
#  'YARD SWITCH - BD CHECK',
#  'UNION (TO ST ANDREW)',
#  'GLENAYR SUBSTATION',
#  'ST. CLAIR WEST TO DUPO',
#  'KENNEDY - MCCOWAN',
#  'ST. GEORGE TO BROADVIE',
#  'CASTLE FRANK TO SHERBO',
#  'SHEPPARD WEST TO ST. C',
#  'LAWRENCE TO BLOOR STAT',
#  'LAWRENCE TO EGLINTON S',
#  'FINCH TO UNION STATION',
#  'ST GEORGE SIGNALS OFFI',
#  'YONGE-UNIVERSITY-SPADI',
#  'ST GEORGE TO FINCH WES',
#  'BAY LOWER STATION',
#  'ATC TERRITORY',
#  'SHEPPARD YONGE',
#  'LAWRENCE WEST TO EGLIN',
#  'WILSON GARAGE',
#  'WELLBECK EMERGENCY',
#  'GREENWOOD TRACK AND ST',
#  'GO PROTOCOL - BARRIE L',
#  'CHANGE OVERS / GENERAL',
#  'NORTHBOUND TO LAWRENCE',
#  'SPADINA TO UNION STATI',
#  'ST CLAIR WEST TO UNION',
#  'DAVISVILLE BUILD-UP',
#  'KIPLING TO KENNEDY',
#  'BATHUSRT STATION',
#  'YORK MILLS CENTRE TRAC',
#  'SYSTEM - WIDE IN THE O',
#  'LAWRENCE SUB STATION',
#  'BROADVIEW TO YONGE',
#  'MCCOWAN PARKING LOT',
#  'UNION TO ST CLAIR WEST',
#  'SHEPPARD WEST TO DOWNS',
#  'SCARBOROUGH CTR STATIO',
#  'YONGE BD STATION (LEAV',
#  'DUPONT MIGRATION POINT',
#  'SHEPPARD-YONGE STATION',
#  'UNION TO BLOOR STATION',
#  'BLOOR TO OSGOODE STATI',
#  'WILSON - ST CLAIR WEST',
#  'FINCH STATION TO DUPON',
#  'ST ANDREW TO BLOOR STA',
#  'KENNEDY TO VICTORIA PA',
#  'VICTORIA PARK TO KENNE',
#  'UNION STATION (TO KING',
#  'BLOOR TO EGLINTON STAT',
#  'DAVISVILLE TO N/O BLOO',
#  'EGLINTON TO BLOOR STAT',
#  'GLENAYR EE',
#  'N/O DAVISVILLE TO N/O',
#  'WILSON STATION TO VMC',
#  'FINCH - NORTH YORK CEN',
#  'BLOOR VIA DUCT',
#  'ST CLAIR TO UNION',
#  'WARDEN TO VICTORIA PAR',
#  'PIONNER VILLAGE STATIO',
#  'YUS/BD/SEPPARD SUBWAY',
#  'WILSON TO ST CLAIR WES',
#  'KEELE TO HIGH PARK STA',
#  'KIPLING TO HIGH PARK',
#  'KIPLING TO KENNEDY STN',
#  'KIPLING TO COXWELL',
#  'BLOOR-DANFORTH LINE',
#  'HIGH PARK TO KEELE',
#  'KENNEDY TO MCCOWAN',
#  'YORKDALE TO FINCH STAT',
#  'UNION TO FINCH',
#  'S/O EGLINTON TO ST CLA']

# %%
import requests
import urllib, json
#address = ["1600+Amphitheatre+Parkway,+Mountain+View,+CA"]
#url = "http://www.datasciencetoolkit.org/maps/api/geocode/json?sensor=false&address=1600+Amphitheatre+Parkway,+Mountain+View,+CA"

# replace space with +sign to create url endpoint

url = "http://www.datasciencetoolkit.org/maps/api/geocode/json?sensor=false&address=1600+Amphitheatre+Parkway,+Mountain+View,+CA"

data = requests.get(url).json()
type(data)
data.keys()
type(data['results'])
type(data['status'])
lat = data['results'][0]['geometry']['location']['lat']
lng = data['results'][0]['geometry']['location']['lng']
print(lat,lng)
# Out:
# 37.423471 -122.086546

# %%
#data = ['MCCOWAN+STATION','SPADINA+YUS+STATION','MAIN+STREET+STATION']
#url = "http://www.datasciencetoolkit.org/maps/api/geocode/json?sensor=false&address=data,+TORONTO"

  
# api-endpoint 
#URL = "http://maps.googleapis.com/maps/api/geocode/json"
#URL = "http://www.datasciencetoolkit.org/maps/api/geocode/json?sensor=false&"
  
# location given here 
#location = "delhi technological university"
#stations = ttc_df['Station']
#stations = [x.replace(" ", "+") for x in stations]
  
# defining a params dict for the parameters to be sent to the API 
#PARAMS = {'sensor': False, 'address':stations} 
  
# sending get request and saving the response as response object 
#r = requests.get(url = URL, params = PARAMS)
  
# extracting data in json format 
#data = r.json() 
  
# extracting latitude, longitude and formatted address  of the first matching location 
#latitude = data['results'][0]['geometry']['location']['lat'] 
#longitude = data['results'][0]['geometry']['location']['lng'] 
#formatted_address = data['results'][0]['formatted_address'] 
  
#printing the output 
#print("Latitude:%s\nLongitude:%s\nFormatted Address:%s"
      #%(latitude, longitude,formatted_address))

# %%
# For creating URL endpoint replace space with + in the station names 
ttc_df['Stations'] = ttc_df['Station']
ttc_df['Stations'] = [x.replace(" ", "+") for x in stations]
#ttc_df['Station']

# %%
#create two empty lists for lat and lng
lat = []
lon = []

for index, row in ttc_df.iterrows():
    
    Station = row['Stations']
    City     = row['City']
    query    = str(Station)+','+str(City)
    URL = "http://www.datasciencetoolkit.org/maps/api/geocode/json?sensor=false&address="
    result = URL + query
    data = requests.get(result).json()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-237-7add86441503> in <module>
#      10     URL = "http://www.datasciencetoolkit.org/maps/api/geocode/json?sensor=false&address="
#      11     result = URL + query
# ---> 12     data = requests.get(result).json()
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
