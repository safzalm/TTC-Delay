# %%
import pandas as pd
import glob

  
    
#ttc-subway-delay-jan-2014-april-2017-0.xlsx
#ttc-subway-delay-may-2017-1.xlsx
#ttc-subway-delay-june-2017-2.xlsx
#ttc-subway-delay-july-2017-3.xlsx
#ttc-subway-delay-august-2017-4.xlsx
#ttc-subway-delay-september-2017-5.xlsx
#ttc-subway-delay-october-2017-6.xlsx
#ttc-subway-delay-november-2017-7.xlsx
#ttc-subway-delay-december-2017-8.xlsx
#ttc-subway-delay-january-2018-9.xlsx
#ttc-subway-delay-february-2018-10.xlsx
#ttc-subway-delay-march-2018-11.xlsx
#ttc-subway-delay-april-2018-12.xlsx
#ttc-subway-delay-may-2018-13.xlsx
#ttc-subway-delay-june-2018-14.xlsx
#ttc-subway-delay-july-2018-15.xlsx
#ttc-subway-delay-august-2018-16.xlsx
#ttc-subway-delay-september-2018-17.xlsx
#ttc-subway-delay-october-2018-18.xlsx
#ttc-subway-delay-november-2018-19.xlsx
#ttc-subway-delay-december-2018-20.xlsx
#ttc-subway-delay-january-2019-21.xlsx
#ttc-subway-delay-february-2019-22.xlsx
#ttc-subway-delay-march-2019-23.xlsx
#ttc-subway-delay-april-2019-24.xlsx
#ttc-subway-delay-may-2019-25.xlsx
#ttc-subway-delay-june-2019-26.xlsx
#
jan2014_april2017 = pd.read_excel("ttc-subway-delay-jan-2014-april-2017-0.xlsx")
may_2017 = pd.read_excel("ttc-subway-delay-may-2017-1.xlsx") 
june_2017 = pd.read_excel("ttc-subway-delay-june-2017-2.xlsx")
july_2017 = pd.read_excel("ttc-subway-delay-july-2017-3.xlsx")
aug_2017 = pd.read_excel("ttc-subway-delay-august-2017-4.xlsx")
sept_2017 = pd.read_excel("ttc-subway-delay-september-2017-5.xlsx")
october_2017 = pd.read_excel("ttc-subway-delay-october-2017-6.xlsx")
nov_2017 = pd.read_excel("ttc-subway-delay-november-2017-7.xlsx")
dec_2017 = pd.read_excel("ttc-subway-delay-december-2017-8.xlsx")
jan_2018 = pd.read_excel("ttc-subway-delay-january-2018-9.xlsx")
feb_2018 = pd.read_excel("ttc-subway-delay-february-2018-10.xlsx")
mar_2018 = pd.read_excel("ttc-subway-delay-march-2018-11.xlsx")
apr_2018 = pd.read_excel("ttc-subway-delay-april-2018-12.xlsx")
may_2018 = pd.read_excel("ttc-subway-delay-may-2018-13.xlsx")
june_2018 = pd.read_excel("ttc-subway-delay-june-2018-14.xlsx")
jul_2018 = pd.read_excel("ttc-subway-delay-july-2018-15.xlsx")
aug_2018 = pd.read_excel("ttc-subway-delay-august-2018-16.xlsx")
sept_2018 = pd.read_excel("ttc-subway-delay-september-2018-17.xlsx")
october_2018 = pd.read_excel("ttc-subway-delay-october-2018-18.xlsx")
nov_2018 = pd.read_excel("ttc-subway-delay-november-2018-19.xlsx")
dec_2018 = pd.read_excel("ttc-subway-delay-december-2018-20.xlsx")
jan_2019 = pd.read_excel("ttc-subway-delay-january-2019-21.xlsx")
feb_2019 = pd.read_excel("ttc-subway-delay-february-2019-22.xlsx")
mar_2019 = pd.read_excel("ttc-subway-delay-march-2019-23.xlsx")
apr_2019 = pd.read_excel("ttc-subway-delay-april-2019-24.xlsx")
may_2019 = pd.read_excel("ttc-subway-delay-may-2019-25.xlsx")
june_2019 = pd.read_excel("ttc-subway-delay-june-2019-26.xlsx")

ttc_subway_delay_jan_2014_june_2019 = [jan2014_april2017,
                                                    may_2017,
                                                    june_2017,
                                                    july_2017, 
                                                    aug_2017,
                                                    sept_2017, 
                                                    october_2017,
                                                    nov_2017,
                                                    dec_2017,
                                                    jan_2018,
                                                    feb_2018,
                                                    mar_2018,
                                                    apr_2018,
                                                    may_2018,
                                                    june_2018, 
                                                    jul_2018,
                                                    aug_2018,
                                                    sept_2018, 
                                                    october_2018, 
                                                    nov_2018,
                                                    dec_2018,
                                                    jan_2019,
                                                    feb_2019,
                                                    mar_2019,
                                                    apr_2019,
                                                    may_2019,
                                                    june_2019]
appended_df = pd.concat(ttc_subway_delay_jan_2014_june_2019)
#appended_df.to_csv("ttc_data.csv", index=False)
appended_df.to_excel("ttc_data.xlsx")

# %%
ttc_df = appended_df

# %%
ttc_df
# Out:
#            Date   Time        Day                 Station   Code  Min Delay  \
# 0    2014-01-01  00:21  Wednesday   VICTORIA PARK STATION  MUPR1         55
# 1    2014-01-01  02:06  Wednesday       HIGH PARK STATION   SUDP          3
# 2    2014-01-01  02:40  Wednesday        SHEPPARD STATION  MUNCA          0
# 3    2014-01-01  03:10  Wednesday       LANSDOWNE STATION   SUDP          3
# 4    2014-01-01  03:20  Wednesday           BLOOR STATION  MUSAN          5
# 5    2014-01-01  03:29  Wednesday        DUFFERIN STATION  MUPAA          0
# 6    2014-01-01  07:31  Wednesday  NORTH YORK CTR STATION  MUNCA          0
# 7    2014-01-01  07:32  Wednesday        SHEPPARD STATION  MUNCA          0
# 8    2014-01-01  07:34  Wednesday           QUEEN STATION  MUNCA          0
# 9    2014-01-01  07:34  Wednesday       RUNNYMEDE STATION  MUNCA          0
# 10   2014-01-01  07:53  Wednesday       ST ANDREW STATION  MUNCA          0
# ...
